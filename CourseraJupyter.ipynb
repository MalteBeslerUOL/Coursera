# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Malte Besler__

# %% [markdown]
# _I am interested in data science because it is a way to explain social phenomena based on evidence. Using all the information available to gain insights into topics I am interested in is an intrinsic motivation for me._

# %% [markdown]
# ### The next cell performs a simple addition.

# %%
13+12
# Out:
# 25

# %% [markdown]
# Look at this horizontal line:
# ***
# 1. This
# 2. is
# 3. a
#     1. Numbered
#     2. List
#
# - This is
# - a bulleted list
# - with a ~~strikethrough~~
#
# And this is a table:
#
# | Hallo! | I hope | you guys |
# | --- | --- | --- |
# | have a | great day | Bye bye! |
